# %%
import numpy as np

def seq2dataset(seq, window_size):
    dataset_X = []
    dataset_Y = []
    
    for i in range(len(seq)-window_size):
        
        subset = seq[i:(i+window_size+1)]
        
        for si in range(len(subset)-1):
            features = code2features(subset[si])            
            dataset_X.append(features)

        dataset_Y.append([code2idx[subset[window_size]]])
        
    return np.array(dataset_X), np.array(dataset_Y)



def code2features(code):
    features = []
    features.append(code2scale[code[0]]/float(max_scale_value))
    features.append(code2length[code[1]])
    return features

code2scale = {'c':0, 'd':1, 'e':2, 'f':3, 'g':4, 'a':5, 'b':6}
code2length = {'4':0, '8':1}
max_scale_value = 6.0

code2idx = {'c4':0, 'd4':1, 'e4':2, 'f4':3, 'g4':4, 'a4':5, 'b4':6,
            'c8':7, 'd8':8, 'e8':9, 'f8':10, 'g8':11, 'a8':12, 'b8':13}

idx2code = {0:'c4', 1:'d4', 2:'e4', 3:'f4', 4:'g4', 5:'a4', 6:'b4',
            7:'c8', 8:'d8', 9:'e8', 10:'f8', 11:'g8', 12:'a8', 13:'b8'}



seq = ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4',
       'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4',
       'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4',
       'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']


import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import tensorflow.keras.utils 

class LossHistory(tf.keras.callbacks.Callback):
    def init(self):
        self.losses = []
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))


x_train, y_train = seq2dataset(seq, window_size = 4)

#x_train = np.reshape(x_train, (50,4,1))
x_train = np.reshape(x_train, (50,4,2))

y_train = tensorflow.keras.utils.to_categorical(y_train)
one_hot_vec_size = y_train.shape[1]

print("one hot encoding vector size is ", one_hot_vec_size)

#
model = tf.keras.Sequential()
#model.add( LSTM( 128, batch_input_shape=(1,4,1), stateful=True ) )
model.add( LSTM( 128, batch_input_shape=(1,4,2), stateful=True ) )
model.add( Dense( one_hot_vec_size, activation='softmax' ) )

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
num_epochs = 200

history = LossHistory()
history.init()

for epoch_idx in range(num_epochs):
    print('epochs : ' + str(epoch_idx))
    model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2, shuffle=False,
             callbacks=[history])
    model.reset_states()


# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.losses)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='best')
plt.show()




scores = model.evaluate(x_train, y_train, batch_size=1)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
model.reset_states()

pred_count = 50
seq_out = ['g8','e8','e4','f8']
pred_out = model.predict(x_train, batch_size=1)

for i in range(pred_count):
    idx = np.argmax(pred_out[i])
    seq_out.append(idx2code[idx])
    
model.reset_states()
print("one step prediction: ", seq_out)

seq_in = ['g8','e8','e4','f8']
seq_out = seq_in
seq_in = [code2idx[it] / float(max_idx_value) for it in seq_in ]

for i in range(pred_count):
    sample_in = np.array(seq_in)
    #sample_in = np.reshape(sample_in, (1,4,1))
    sample_in = np.reshape(sample_in, (1,4,2))
    pred_out = model.predict(sample_in)
    idx = np.argmax(pred_out)
    seq_out.append(idx2code[idx])
    seq_in.append(idx/float(max_idx_value))
    seq_in.pop(0)

model.reset_states()
print("full song prediction : ", seq_out )
# Out:
# one hot encoding vector size is  12
# epochs : 0
# 50/50 - 0s - loss: 2.3298 - accuracy: 0.3000
# epochs : 1
# 50/50 - 0s - loss: 2.0140 - accuracy: 0.3400
# epochs : 2
# 50/50 - 0s - loss: 1.9677 - accuracy: 0.3400
# epochs : 3
# 50/50 - 0s - loss: 1.9482 - accuracy: 0.3400
# epochs : 4
# 50/50 - 0s - loss: 1.9366 - accuracy: 0.3400
# epochs : 5
# 50/50 - 0s - loss: 1.9280 - accuracy: 0.3400
# epochs : 6
# 50/50 - 0s - loss: 1.9211 - accuracy: 0.3400
# epochs : 7
# 50/50 - 0s - loss: 1.9152 - accuracy: 0.3400
# epochs : 8
# 50/50 - 0s - loss: 1.9097 - accuracy: 0.3400
# epochs : 9
# 50/50 - 0s - loss: 1.9042 - accuracy: 0.3400
# epochs : 10
# 50/50 - 0s - loss: 1.8987 - accuracy: 0.3400
# epochs : 11
# 50/50 - 0s - loss: 1.8919 - accuracy: 0.3400
# epochs : 12
# 50/50 - 0s - loss: 1.8821 - accuracy: 0.3600
# epochs : 13
# 50/50 - 0s - loss: 1.8837 - accuracy: 0.3600
# epochs : 14
# 50/50 - 0s - loss: 1.8645 - accuracy: 0.3600
# epochs : 15
# 50/50 - 0s - loss: 1.8860 - accuracy: 0.3600
# epochs : 16
# 50/50 - 0s - loss: 1.8200 - accuracy: 0.3600
# epochs : 17
# 50/50 - 0s - loss: 1.8385 - accuracy: 0.3600
# epochs : 18
# 50/50 - 0s - loss: 1.8201 - accuracy: 0.3600
# epochs : 19
# 50/50 - 0s - loss: 1.7328 - accuracy: 0.3400
# epochs : 20
# 50/50 - 0s - loss: 1.8507 - accuracy: 0.3200
# epochs : 21
# 50/50 - 0s - loss: 1.7148 - accuracy: 0.3800
# epochs : 22
# 50/50 - 0s - loss: 1.6783 - accuracy: 0.3200
# epochs : 23
# 50/50 - 0s - loss: 1.6206 - accuracy: 0.3400
# epochs : 24
# 50/50 - 0s - loss: 1.5388 - accuracy: 0.4400
# epochs : 25
# 50/50 - 0s - loss: 1.6524 - accuracy: 0.4200
# epochs : 26
# 50/50 - 0s - loss: 1.7120 - accuracy: 0.4200
# epochs : 27
# 50/50 - 0s - loss: 1.4954 - accuracy: 0.4200
# epochs : 28
# 50/50 - 0s - loss: 1.7631 - accuracy: 0.3800
# epochs : 29
# 50/50 - 0s - loss: 1.4863 - accuracy: 0.3800
# epochs : 30
# 50/50 - 0s - loss: 1.5383 - accuracy: 0.3600
# epochs : 31
# 50/50 - 0s - loss: 1.6001 - accuracy: 0.3400
# epochs : 32
# 50/50 - 0s - loss: 1.4106 - accuracy: 0.5200
# epochs : 33
# 50/50 - 0s - loss: 1.2861 - accuracy: 0.5200
# epochs : 34
# 50/50 - 0s - loss: 1.3922 - accuracy: 0.4000
# epochs : 35
# 50/50 - 0s - loss: 1.3598 - accuracy: 0.3800
# epochs : 36
# 50/50 - 0s - loss: 1.4366 - accuracy: 0.4400
# epochs : 37
# 50/50 - 0s - loss: 1.2677 - accuracy: 0.4800
# epochs : 38
# 50/50 - 0s - loss: 1.2051 - accuracy: 0.5400
# epochs : 39
# 50/50 - 0s - loss: 0.9530 - accuracy: 0.6200
# epochs : 40
# 50/50 - 0s - loss: 1.2367 - accuracy: 0.4400
# epochs : 41
# 50/50 - 0s - loss: 1.3297 - accuracy: 0.5000
# epochs : 42
# 50/50 - 0s - loss: 1.1568 - accuracy: 0.5000
# epochs : 43
# 50/50 - 0s - loss: 1.0273 - accuracy: 0.5200
# epochs : 44
# 50/50 - 0s - loss: 1.1666 - accuracy: 0.5000
# epochs : 45
# 50/50 - 0s - loss: 1.1411 - accuracy: 0.5000
# epochs : 46
# 50/50 - 0s - loss: 0.9205 - accuracy: 0.6400
# epochs : 47
# 50/50 - 0s - loss: 1.0555 - accuracy: 0.7000
# epochs : 48
# 50/50 - 0s - loss: 0.9894 - accuracy: 0.6200
# epochs : 49
# 50/50 - 0s - loss: 1.0393 - accuracy: 0.6400
# epochs : 50
# 50/50 - 0s - loss: 0.9192 - accuracy: 0.6400
# epochs : 51
# 50/50 - 0s - loss: 0.8626 - accuracy: 0.6400
# epochs : 52
# 50/50 - 0s - loss: 0.8155 - accuracy: 0.7400
# epochs : 53
# 50/50 - 0s - loss: 1.1035 - accuracy: 0.5800
# epochs : 54
# 50/50 - 0s - loss: 0.9398 - accuracy: 0.6000
# epochs : 55
# 50/50 - 0s - loss: 1.0769 - accuracy: 0.5800
# epochs : 56
# 50/50 - 0s - loss: 0.8330 - accuracy: 0.6400
# epochs : 57
# 50/50 - 0s - loss: 0.7060 - accuracy: 0.8000
# epochs : 58
# 50/50 - 0s - loss: 0.7071 - accuracy: 0.7600
# epochs : 59
# 50/50 - 0s - loss: 1.3791 - accuracy: 0.5600
# epochs : 60
# 50/50 - 0s - loss: 0.8907 - accuracy: 0.6600
# epochs : 61
# 50/50 - 0s - loss: 0.6892 - accuracy: 0.7800
# epochs : 62
# 50/50 - 0s - loss: 0.5222 - accuracy: 0.8800
# epochs : 63
# 50/50 - 0s - loss: 0.6266 - accuracy: 0.7600
# epochs : 64
# 50/50 - 0s - loss: 0.7341 - accuracy: 0.7600
# epochs : 65
# 50/50 - 0s - loss: 0.5781 - accuracy: 0.8000
# epochs : 66
# 50/50 - 0s - loss: 0.4007 - accuracy: 0.9400
# epochs : 67
# 50/50 - 0s - loss: 0.4177 - accuracy: 0.8400
# epochs : 68
# 50/50 - 0s - loss: 0.3057 - accuracy: 0.9600
# epochs : 69
# 50/50 - 0s - loss: 0.2631 - accuracy: 0.9400
# epochs : 70
# 50/50 - 0s - loss: 0.1911 - accuracy: 0.9800
# epochs : 71
# 50/50 - 0s - loss: 0.1497 - accuracy: 0.9800
# epochs : 72
# 50/50 - 0s - loss: 0.2097 - accuracy: 0.9400
# epochs : 73
# 50/50 - 0s - loss: 1.1039 - accuracy: 0.7400
# epochs : 74
# 50/50 - 0s - loss: 1.1469 - accuracy: 0.6200
# epochs : 75
# 50/50 - 0s - loss: 1.1111 - accuracy: 0.6200
# epochs : 76
# 50/50 - 0s - loss: 0.8367 - accuracy: 0.7400
# epochs : 77
# 50/50 - 0s - loss: 0.5789 - accuracy: 0.8000
# epochs : 78
# 50/50 - 0s - loss: 0.3840 - accuracy: 0.8600
# epochs : 79
# 50/50 - 0s - loss: 0.3002 - accuracy: 0.9200
# epochs : 80
# 50/50 - 0s - loss: 0.2075 - accuracy: 1.0000
# epochs : 81
# 50/50 - 0s - loss: 0.1737 - accuracy: 1.0000
# epochs : 82
# 50/50 - 0s - loss: 0.1484 - accuracy: 0.9800
# epochs : 83
# 50/50 - 0s - loss: 0.1896 - accuracy: 0.9400
# epochs : 84
# 50/50 - 0s - loss: 0.6167 - accuracy: 0.7400
# epochs : 85
# 50/50 - 0s - loss: 0.9409 - accuracy: 0.6600
# epochs : 86
# 50/50 - 0s - loss: 0.7094 - accuracy: 0.7800
# epochs : 87
# 50/50 - 0s - loss: 0.4895 - accuracy: 0.8600
# epochs : 88
# 50/50 - 0s - loss: 0.6920 - accuracy: 0.7400
# epochs : 89
# 50/50 - 0s - loss: 0.7128 - accuracy: 0.8200
# epochs : 90
# 50/50 - 0s - loss: 0.7444 - accuracy: 0.7000
# epochs : 91
# 50/50 - 0s - loss: 0.3921 - accuracy: 0.8800
# epochs : 92
# 50/50 - 0s - loss: 0.2185 - accuracy: 0.9400
# epochs : 93
# 50/50 - 0s - loss: 0.3344 - accuracy: 0.8800
# epochs : 94
# 50/50 - 0s - loss: 0.3331 - accuracy: 0.8800
# epochs : 95
# 50/50 - 0s - loss: 0.1793 - accuracy: 0.9600
# epochs : 96
# 50/50 - 0s - loss: 0.1090 - accuracy: 0.9800
# epochs : 97
# 50/50 - 0s - loss: 0.0633 - accuracy: 1.0000
# epochs : 98
# 50/50 - 0s - loss: 0.0545 - accuracy: 1.0000
# epochs : 99
# 50/50 - 0s - loss: 0.0398 - accuracy: 1.0000
# epochs : 100
# 50/50 - 0s - loss: 0.0358 - accuracy: 1.0000
# epochs : 101
# 50/50 - 0s - loss: 0.0300 - accuracy: 1.0000
# epochs : 102
# 50/50 - 0s - loss: 0.0274 - accuracy: 1.0000
# epochs : 103
# 50/50 - 0s - loss: 0.0238 - accuracy: 1.0000
# epochs : 104
# 50/50 - 0s - loss: 0.0217 - accuracy: 1.0000
# epochs : 105
# 50/50 - 0s - loss: 0.0197 - accuracy: 1.0000
# epochs : 106
# 50/50 - 0s - loss: 0.0179 - accuracy: 1.0000
# epochs : 107
# 50/50 - 0s - loss: 0.0166 - accuracy: 1.0000
# epochs : 108
# 50/50 - 0s - loss: 0.0153 - accuracy: 1.0000
# epochs : 109
# 50/50 - 0s - loss: 0.0142 - accuracy: 1.0000
# epochs : 110
# 50/50 - 0s - loss: 0.0132 - accuracy: 1.0000
# epochs : 111
# 50/50 - 0s - loss: 0.0123 - accuracy: 1.0000
# epochs : 112
# 50/50 - 0s - loss: 0.0115 - accuracy: 1.0000
# epochs : 113
# 50/50 - 0s - loss: 0.0108 - accuracy: 1.0000
# epochs : 114
# 50/50 - 0s - loss: 0.0102 - accuracy: 1.0000
# epochs : 115
# 50/50 - 0s - loss: 0.0096 - accuracy: 1.0000
# epochs : 116
# 50/50 - 0s - loss: 0.0091 - accuracy: 1.0000
# epochs : 117
# 50/50 - 0s - loss: 0.0085 - accuracy: 1.0000
# epochs : 118
# 50/50 - 0s - loss: 0.0081 - accuracy: 1.0000
# epochs : 119
# 50/50 - 0s - loss: 0.0077 - accuracy: 1.0000
# epochs : 120
# 50/50 - 0s - loss: 0.0073 - accuracy: 1.0000
# epochs : 121
# 50/50 - 0s - loss: 0.0069 - accuracy: 1.0000
# epochs : 122
# 50/50 - 0s - loss: 0.0065 - accuracy: 1.0000
# epochs : 123
# 50/50 - 0s - loss: 0.0062 - accuracy: 1.0000
# epochs : 124
# 50/50 - 0s - loss: 0.0059 - accuracy: 1.0000
# epochs : 125
# 50/50 - 0s - loss: 0.0056 - accuracy: 1.0000
# epochs : 126
# 50/50 - 0s - loss: 0.0053 - accuracy: 1.0000
# epochs : 127
# 50/50 - 0s - loss: 0.0051 - accuracy: 1.0000
# epochs : 128
# 50/50 - 0s - loss: 0.0048 - accuracy: 1.0000
# epochs : 129
# 50/50 - 0s - loss: 0.0046 - accuracy: 1.0000
# epochs : 130
# 50/50 - 0s - loss: 0.0044 - accuracy: 1.0000
# epochs : 131
# 50/50 - 0s - loss: 0.0042 - accuracy: 1.0000
# epochs : 132
# 50/50 - 0s - loss: 0.0040 - accuracy: 1.0000
# epochs : 133
# 50/50 - 0s - loss: 0.0038 - accuracy: 1.0000
# epochs : 134
# 50/50 - 0s - loss: 0.0036 - accuracy: 1.0000
# epochs : 135
# 50/50 - 0s - loss: 0.0035 - accuracy: 1.0000
# epochs : 136
# 50/50 - 0s - loss: 0.0033 - accuracy: 1.0000
# epochs : 137
# 50/50 - 0s - loss: 0.0032 - accuracy: 1.0000
# epochs : 138
# 50/50 - 0s - loss: 0.0030 - accuracy: 1.0000
# epochs : 139
# 50/50 - 0s - loss: 0.0029 - accuracy: 1.0000
# epochs : 140
# 50/50 - 0s - loss: 0.0028 - accuracy: 1.0000
# epochs : 141
# 50/50 - 0s - loss: 0.0027 - accuracy: 1.0000
# epochs : 142
# 50/50 - 0s - loss: 0.0026 - accuracy: 1.0000
# epochs : 143
# 50/50 - 0s - loss: 0.0025 - accuracy: 1.0000
# epochs : 144
# 50/50 - 0s - loss: 0.0024 - accuracy: 1.0000
# epochs : 145
# 50/50 - 0s - loss: 0.0023 - accuracy: 1.0000
# epochs : 146
# 50/50 - 0s - loss: 0.0022 - accuracy: 1.0000
# epochs : 147
# 50/50 - 0s - loss: 0.0021 - accuracy: 1.0000
# epochs : 148
# 50/50 - 0s - loss: 0.0020 - accuracy: 1.0000
# epochs : 149
# 50/50 - 0s - loss: 0.0019 - accuracy: 1.0000
# epochs : 150
# 50/50 - 0s - loss: 0.0019 - accuracy: 1.0000
# epochs : 151
# 50/50 - 0s - loss: 0.0018 - accuracy: 1.0000
# epochs : 152
# 50/50 - 0s - loss: 0.0017 - accuracy: 1.0000
# epochs : 153
# 50/50 - 0s - loss: 0.0017 - accuracy: 1.0000
# epochs : 154
# 50/50 - 0s - loss: 0.0016 - accuracy: 1.0000
# epochs : 155
# 50/50 - 0s - loss: 0.0016 - accuracy: 1.0000
# epochs : 156
# 50/50 - 0s - loss: 0.0015 - accuracy: 1.0000
# epochs : 157
# 50/50 - 0s - loss: 0.0015 - accuracy: 1.0000
# epochs : 158
# 50/50 - 0s - loss: 0.0014 - accuracy: 1.0000
# epochs : 159
# 50/50 - 0s - loss: 0.0014 - accuracy: 1.0000
# epochs : 160
# 50/50 - 0s - loss: 0.0013 - accuracy: 1.0000
# epochs : 161
# 50/50 - 0s - loss: 0.0013 - accuracy: 1.0000
# epochs : 162
# 50/50 - 0s - loss: 0.0012 - accuracy: 1.0000
# epochs : 163
# 50/50 - 0s - loss: 0.0012 - accuracy: 1.0000
# epochs : 164
# 50/50 - 0s - loss: 0.0011 - accuracy: 1.0000
# epochs : 165
# 50/50 - 0s - loss: 0.0011 - accuracy: 1.0000
# epochs : 166
# 50/50 - 0s - loss: 0.0011 - accuracy: 1.0000
# epochs : 167
# 50/50 - 0s - loss: 0.0010 - accuracy: 1.0000
# epochs : 168
# 50/50 - 0s - loss: 9.9629e-04 - accuracy: 1.0000
# epochs : 169
# 50/50 - 0s - loss: 9.6294e-04 - accuracy: 1.0000
# epochs : 170
# 50/50 - 0s - loss: 9.3096e-04 - accuracy: 1.0000
# epochs : 171
# 50/50 - 0s - loss: 8.9986e-04 - accuracy: 1.0000
# epochs : 172
# 50/50 - 0s - loss: 8.7020e-04 - accuracy: 1.0000
# epochs : 173
# 50/50 - 0s - loss: 8.4132e-04 - accuracy: 1.0000
# epochs : 174
# 50/50 - 0s - loss: 8.1379e-04 - accuracy: 1.0000
# epochs : 175
# 50/50 - 0s - loss: 7.8694e-04 - accuracy: 1.0000
# epochs : 176
# 50/50 - 0s - loss: 7.6137e-04 - accuracy: 1.0000
# epochs : 177
# 50/50 - 0s - loss: 7.3651e-04 - accuracy: 1.0000
# epochs : 178
# 50/50 - 0s - loss: 7.1270e-04 - accuracy: 1.0000
# epochs : 179
# 50/50 - 0s - loss: 6.8963e-04 - accuracy: 1.0000
# epochs : 180
# 50/50 - 0s - loss: 6.6749e-04 - accuracy: 1.0000
# epochs : 181
# 50/50 - 0s - loss: 6.4609e-04 - accuracy: 1.0000
# epochs : 182
# 50/50 - 0s - loss: 6.2542e-04 - accuracy: 1.0000
# epochs : 183
# 50/50 - 0s - loss: 6.0552e-04 - accuracy: 1.0000
# epochs : 184
# 50/50 - 0s - loss: 5.8626e-04 - accuracy: 1.0000
# epochs : 185
# 50/50 - 0s - loss: 5.6766e-04 - accuracy: 1.0000
# epochs : 186
# 50/50 - 0s - loss: 5.4971e-04 - accuracy: 1.0000
# epochs : 187
# 50/50 - 0s - loss: 5.3230e-04 - accuracy: 1.0000
# epochs : 188
# 50/50 - 0s - loss: 5.1550e-04 - accuracy: 1.0000
# epochs : 189
# 50/50 - 0s - loss: 4.9925e-04 - accuracy: 1.0000
# epochs : 190
# 50/50 - 0s - loss: 4.8352e-04 - accuracy: 1.0000
# epochs : 191
# 50/50 - 0s - loss: 4.6832e-04 - accuracy: 1.0000
# epochs : 192
# 50/50 - 0s - loss: 4.5361e-04 - accuracy: 1.0000
# epochs : 193
# 50/50 - 0s - loss: 4.3936e-04 - accuracy: 1.0000
# epochs : 194
# 50/50 - 0s - loss: 4.2561e-04 - accuracy: 1.0000
# epochs : 195
# 50/50 - 0s - loss: 4.1233e-04 - accuracy: 1.0000
# epochs : 196
# 50/50 - 0s - loss: 3.9951e-04 - accuracy: 1.0000
# epochs : 197
# 50/50 - 0s - loss: 3.8711e-04 - accuracy: 1.0000
# epochs : 198
# 50/50 - 0s - loss: 3.7516e-04 - accuracy: 1.0000
# epochs : 199
# 50/50 - 0s - loss: 3.6362e-04 - accuracy: 1.0000
# 50/50 [==============================] - 0s 2ms/step - loss: 3.5711e-04 - accuracy: 1.0000
# accuracy: 100.00%
# one step prediction:  ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4', 'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4', 'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4', 'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b93cb13ac7ae> in <module>
#     119     sample_in = np.array(seq_in)
#     120     #sample_in = np.reshape(sample_in, (1,4,1))
# --> 121     sample_in = np.reshape(sample_in, (1,4,2))
#     122     pred_out = model.predict(sample_in)
#     123     idx = np.argmax(pred_out)
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~\anaconda3\envs\venv\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# ~\anaconda3\envs\venv\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 4 into shape (1,4,2)
